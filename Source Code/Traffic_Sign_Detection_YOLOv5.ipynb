# %% [markdown]
# <a href="https://colab.research.google.com/github/imqp/CS114.N21.KHCL/blob/main/Traffic_Sign_Detection_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Clone model and install environment

# %cd "/content/drive/MyDrive/FinalProject"
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd "/content/drive/MyDrive/FinalProject/yolov5"
# %pip install -qr requirements.txt comet_ml  # install environment
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.9/626.9 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 91.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.2/213.2 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 kB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.2/166.8 GB disk)

# %%
# Download datasets

# %cd "/content/drive/MyDrive/FinalProject/yolov5/data"
# !gdown --id "1zmKuX5NYDQsjyuFHTnFAWf1xg_RWyDFw"
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5/data
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1zmKuX5NYDQsjyuFHTnFAWf1xg_RWyDFw
# To: /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5/data/data.zip
# 100% 389M/389M [00:02<00:00, 165MB/s]

# %%
# !rm -r images
# !rm -r labels

# !unzip -o data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/train/IMG_2357-015.jpg
#   inflating: images/train/IMG_2357-020.jpg
#   inflating: images/train/IMG_2357-048.jpg
#   inflating: images/train/IMG_2357-055.jpg
#   inflating: images/train/IMG_2357-056.jpg
#   inflating: images/train/IMG_2357-066.jpg
#   inflating: images/train/IMG_2357-068.jpg
#   inflating: images/train/IMG_2357-069.jpg
#   inflating: images/train/IMG_2357-071.jpg
#   inflating: images/train/IMG_2358-008.jpg
#   inflating: images/train/IMG_2358-034.jpg
#   inflating: images/train/IMG_2359-001.jpg
#   inflating: images/train/IMG_2359-004.jpg
#   inflating: images/train/IMG_236.JPG
#   inflating: images/train/IMG_2360-004.jpg
#   inflating: images/train/IMG_2360-005.jpg
#   inflating: images/train/IMG_2361-004.jpg
#   inflating: images/train/IMG_2361-010.jpg
#   inflating: images/train/IMG_2361-015.jpg
#   inflating: images/train/IMG_2361-018.jpg
#   inflating: images/train/IMG_2361-023.jpg
# ...

# %%
# Number of train images

# %cd "images/train"
# !ls -1 | wc -l
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5/data/images/train
# 2418

# %%
# download TrafficSign.yaml

# %cd "/content/drive/MyDrive/FinalProject/yolov5/data"
# !gdown --id "1azV5Zdb9xjalKZs3koF4G0p1IDkXD9p1"
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5/data
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1azV5Zdb9xjalKZs3koF4G0p1IDkXD9p1
# To: /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5/data/TrafficSign.yaml
# 100% 2.92k/2.92k [00:00<00:00, 17.8MB/s]

# %%
# %cd ..
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5

# %%
# !python train.py --img 640 --batch 32 --epochs 250 --data TrafficSign.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=TrafficSign.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=250, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# ...

# %%
# Validate model

# %%
# Du doan anh

# %%
# %cd /content/drive/MyDrive/FinalProject/yolov5/data/
# !gdown --id "14OIOCC8aIIzw8DB72JW1RY0FX2yFxMpn"

# %%
# !unzip -o test.zip
# Out:
# Archive:  test.zip
#   inflating: test/1.jpg
#   inflating: test/10.jpeg
#   inflating: test/11.jpeg
#   inflating: test/12.jpeg
#   inflating: test/13.jpeg
#   inflating: test/2.jpg
#   inflating: test/3.jpg
#   inflating: test/4.jpg
#   inflating: test/5.jpg
#   inflating: test/6.jpg
#   inflating: test/7.jpg
#   inflating: test/8.jpeg
#   inflating: test/9.jpeg

# %%
# %cd ..
# !python detect.py --weights "/content/drive/MyDrive/FinalProject/yolov5/runs/train/exp/weights/best.pt" --img 640 --conf 0.25 --source data/test
# Out:
# /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5
# detect: weights=['/content/drive/MyDrive/FinalProject/yolov5/runs/train/exp/weights/best.pt'], source=data/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7285219 parameters, 0 gradients, 16.6 GFLOPs
# image 1/13 /content/drive/.shortcut-targets-by-id/14jPsQEGR4krZN_UhzrWR9os7Meda71Xa/FinalProject/yolov5/data/test/1.jpg: 640x640 1 Cam do xe, 1 Chi duong, 5.6ms
# ...
